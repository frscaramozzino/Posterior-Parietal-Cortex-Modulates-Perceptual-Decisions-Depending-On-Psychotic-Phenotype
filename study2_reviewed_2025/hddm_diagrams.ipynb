# %%
import daft
import matplotlib.pyplot as plt

pgm = daft.PGM(aspect=3, dpi=300)

# ----------------------------
# Hyperparameters
# ----------------------------
pgm.add_node("mu_v", r"$\mu_v$", 0.5, 5, fontsize=6)
pgm.add_node("mu_a", r"$\mu_a$", 2, 5, fontsize=6)
pgm.add_node("mu_t", r"$\mu_t$", 3.5, 5, fontsize=6)

pgm.add_node("sigma_v", r"$\sigma_v$", 0.5, 4, fontsize=6)
pgm.add_node("sigma_a", r"$\sigma_a$", 2, 4, fontsize=6)
pgm.add_node("sigma_t", r"$\sigma_t$", 3.5, 4, fontsize=6)

# ----------------------------
# Condition-level parameters
# ----------------------------
pgm.add_node("v_cond", r"$v_{\text{PDI/CAPS × Session × Coherence}}$", 0.5, 3, fontsize=6)
pgm.add_node("a_cond", r"$a_{\text{PDI/CAPS × Session × Coherence}}$", 2, 3, fontsize=6)
pgm.add_node("t_cond", r"$t_{\text{PDI/CAPS × Session × Coherence}}$", 3.5, 3, fontsize=6)

# ----------------------------
# Trial-level observed data
# ----------------------------
pgm.add_node("rt", r"$RT_{i,t}$", 1.5, 1, observed=True, fontsize=9)
pgm.add_node("response", r"$Response_{i,t}$", 3, 1, observed=True, fontsize=9)

# ----------------------------
# Edges
# ----------------------------
for param in ["v", "a", "t"]:
    pgm.add_edge(f"mu_{param}", f"{param}_cond")
    pgm.add_edge(f"sigma_{param}", f"{param}_cond")
    pgm.add_edge(f"{param}_cond", "rt")
    pgm.add_edge(f"{param}_cond", "response")

# ----------------------------
# Plates
# ----------------------------

# Hyperpriors plate
pgm.add_plate(daft.Plate(
    [-0.5, 3.5, 5, 1.8],
    label="Hyperpriors",
    fontsize=6
))

# Condition plate
pgm.add_plate(daft.Plate(
    [-0.5, 1.8, 5, 1.5],
    label="PDI/CAPS=Low/High\nSession=Sham/TMS\nCoherence=Low/High",
    fontsize=6
))

# Trial plate
pgm.add_plate(daft.Plate(
    [0.64, 0.2, 3.2, 1.2],
    label=r"$Trials: 2720$" "\n" r"$\ RT_{i,t},Response_{i,t}∼DDM(v_{cond},a_{cond},t_{cond})$",
    fontsize=6
))

# Render
pgm.render()

# Save neatly with bounding box
plt.tight_layout()
plt.savefig("hddm_tms_pdi_caps_diagram.png", dpi=300, bbox_inches="tight")

plt.show()
# Out:
# /var/folders/cz/jbpqkvc936gc0lrwm6908lsh0000gn/T/ipykernel_15792/746978478.py:68: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import daft
import matplotlib.pyplot as plt

pgm = daft.PGM(aspect=3, dpi=300)

# ----------------------------
# Hyperparameters
# ----------------------------
pgm.add_node("mu_v", r"$\mu_v$", 0.5, 5, fontsize=6)
pgm.add_node("mu_a", r"$\mu_a$", 2, 5, fontsize=6)
pgm.add_node("mu_t", r"$\mu_t$", 3.5, 5, fontsize=6)

pgm.add_node("sigma_v", r"$\sigma_v$", 0.5, 4, fontsize=6)
pgm.add_node("sigma_a", r"$\sigma_a$", 2, 4, fontsize=6)
pgm.add_node("sigma_t", r"$\sigma_t$", 3.5, 4, fontsize=6)

# ----------------------------
# Condition-level parameters
# ----------------------------
pgm.add_node("v_cond", r"$v_{\text{CAPS × Session × Coherence}}$", 0.5, 3, fontsize=6)
pgm.add_node("a_cond", r"$a_{\text{CAPS × Session × Coherence}}$", 2, 3, fontsize=6)
pgm.add_node("t_cond", r"$t_{\text{CAPS × Session × Coherence}}$", 3.5, 3, fontsize=6)

# ----------------------------
# Trial-level observed data
# ----------------------------
pgm.add_node("rt", r"$RT_{i,t}$", 1.5, 1, observed=True, fontsize=9)
pgm.add_node("response", r"$Response_{i,t}$", 3, 1, observed=True, fontsize=9)

# ----------------------------
# Edges
# ----------------------------
for param in ["v", "a", "t"]:
    pgm.add_edge(f"mu_{param}", f"{param}_cond")
    pgm.add_edge(f"sigma_{param}", f"{param}_cond")
    pgm.add_edge(f"{param}_cond", "rt")
    pgm.add_edge(f"{param}_cond", "response")

# ----------------------------
# Plates
# ----------------------------

# Hyperpriors plate
pgm.add_plate(daft.Plate(
    [-0.5, 3.5, 5, 1.8],  # x0, y0, width, height
    label="Hyperpriors",
    fontsize=6
))

# Condition plate
pgm.add_plate(daft.Plate(
    [-0.5, 1.8, 5, 1.5],
    label="\nCAPS=Low/High\nSession=Sham/TMS\nCoherence=Low/High",
    fontsize=6
))

# Trial plate
pgm.add_plate(daft.Plate(
    [0.64, 0.2, 3.2, 1.2],
    label="Trials: 2720",
    fontsize=6
))

# Render
pgm.render()
# Save to file
plt.tight_layout()  # optional but helps with spacing
plt.savefig("hddm_tms_caps_c_diagram.png", dpi=300, bbox_inches="tight")  # PNG
# plt.savefig("hddm_hyperpriors_diagram.pdf", dpi=300, bbox_inches="tight")  # PDF version

plt.show()
# Out:
# /var/folders/cz/jbpqkvc936gc0lrwm6908lsh0000gn/T/ipykernel_47230/936887511.py:67: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()  # optional but helps with spacing

# %%
import daft
import matplotlib.pyplot as plt

pgm = daft.PGM(aspect=3, dpi=300)

# ----------------------------
# Hyperparameters
# ----------------------------
pgm.add_node("mu_v", r"$\mu_v$", 0.5, 5, fontsize=6)
pgm.add_node("mu_a", r"$\mu_a$", 2, 5, fontsize=6)
pgm.add_node("mu_t", r"$\mu_t$", 3.5, 5, fontsize=6)

pgm.add_node("sigma_v", r"$\sigma_v$", 0.5, 4, fontsize=6)
pgm.add_node("sigma_a", r"$\sigma_a$", 2, 4, fontsize=6)
pgm.add_node("sigma_t", r"$\sigma_t$", 3.5, 4, fontsize=6)

# ----------------------------
# Condition-level parameters
# ----------------------------
pgm.add_node("v_cond", r"$v_{\text{PDI × Session × Coherence}}$", 0.5, 3, fontsize=6)
pgm.add_node("a_cond", r"$a_{\text{PDI × Session × Coherence}}$", 2, 3, fontsize=6)
pgm.add_node("t_cond", r"$t_{\text{PDI × Session × Coherence}}$", 3.5, 3, fontsize=6)

# ----------------------------
# Trial-level observed data
# ----------------------------
pgm.add_node("rt", r"$RT_{i,t}$", 1.5, 1, observed=True, fontsize=9)
pgm.add_node("response", r"$Response_{i,t}$", 3, 1, observed=True, fontsize=9)

# ----------------------------
# Edges
# ----------------------------
for param in ["v", "a", "t"]:
    pgm.add_edge(f"mu_{param}", f"{param}_cond")
    pgm.add_edge(f"sigma_{param}", f"{param}_cond")
    pgm.add_edge(f"{param}_cond", "rt")
    pgm.add_edge(f"{param}_cond", "response")

# ----------------------------
# Plates
# ----------------------------
pgm.add_plate(daft.Plate(
    [-0.5, 3.5, 5, 1.8],
    label="Hyperpriors",
    fontsize=6
))

pgm.add_plate(daft.Plate(
    [-0.5, 1.8, 5, 1.5],
    label="\nPDI=Low/High\nSession=Sham/TMS\nCoherence=Low/High",
    fontsize=6
))

pgm.add_plate(daft.Plate(
    [0.64, 0.2, 3.2, 1.2],
    label="Trials: 2720",
    fontsize=6
))

# Render PGM
fig = pgm.render()
plt.tight_layout()

# --------------------------------------------------
# Add mathematical description (like Wiecki et al. 2013)
# --------------------------------------------------

plt.text(
    -0.5, -0.1,
    r"""
Condition-level distributions:
\[
v_{g,s,c} \sim \mathcal{N}(\mu_v,\,\sigma_v), \quad
a_{g,s,c} \sim \mathcal{N}(\mu_a,\,\sigma_a), \quad
t_{g,s,c} \sim \mathcal{N}(\mu_t,\,\sigma_t)
\]

Trial likelihood:
\[
(RT_{i,t},\,C_{i,t}) \sim \mathrm{DDM}(v_{g,s,c},\, a_{g,s,c},\, t_{g,s,c})
\]
""",
    fontsize=8,
    va="top",
)

# Save file
plt.savefig("hddm_tms_pdi_c_diagram_with_math.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# /var/folders/cz/jbpqkvc936gc0lrwm6908lsh0000gn/T/ipykernel_97754/1909599217.py:62: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import daft
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams["text.usetex"] = False
import matplotlib.pyplot as plt
import matplotlib
import math

# Enable LaTeX
matplotlib.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
})

pgm = daft.PGM(aspect=3, dpi=300)

# ----------------------------
# Hyperparameters
# ----------------------------
pgm.add_node("mu_v", r"$\mu_v$", 0.5, 5, fontsize=6)
pgm.add_node("mu_a", r"$\mu_a$", 2, 5, fontsize=6)
pgm.add_node("mu_t", r"$\mu_t$", 3.5, 5, fontsize=6)

pgm.add_node("sigma_v", r"$\sigma_v$", 0.5, 4, fontsize=6)
pgm.add_node("sigma_a", r"$\sigma_a$", 2, 4, fontsize=6)
pgm.add_node("sigma_t", r"$\sigma_t$", 3.5, 4, fontsize=6)

# ----------------------------
# Condition-level parameters
# ----------------------------
pgm.add_node("v_cond", r"$v_{\text{PDI × Session × Coherence}}$", 0.5, 3, fontsize=6)
pgm.add_node("a_cond", r"$a_{\text{PDI × Session × Coherence}}$", 2, 3, fontsize=6)
pgm.add_node("t_cond", r"$t_{\text{PDI × Session × Coherence}}$", 3.5, 3, fontsize=6)

# ----------------------------
# Trial-level observed data
# ----------------------------
pgm.add_node("rt", r"$RT_{i,t}$", 1.5, 1, observed=True, fontsize=9)
pgm.add_node("response", r"$Response_{i,t}$", 3, 1, observed=True, fontsize=9)

# ----------------------------
# Edges
# ----------------------------
for param in ["v", "a", "t"]:
    pgm.add_edge(f"mu_{param}", f"{param}_cond")
    pgm.add_edge(f"sigma_{param}", f"{param}_cond")
    pgm.add_edge(f"{param}_cond", "rt")
    pgm.add_edge(f"{param}_cond", "response")

# ----------------------------
# Plates
# ----------------------------
pgm.add_plate(daft.Plate(
    [-0.5, 3.5, 5, 1.8],
    label="Hyperpriors",
    fontsize=6
))

pgm.add_plate(daft.Plate(
    [-0.5, 1.8, 5, 1.5],
    label="\nPDI=Low/High\nSession=Sham/TMS\nCoherence=Low/High",
    fontsize=6
))

pgm.add_plate(daft.Plate(
    [0.64, 0.2, 3.2, 1.2],
    label="Trials: 2720",
    fontsize=6
))

# Render PGM
fig = pgm.render()
plt.tight_layout()

# --------------------------------------------------
# Add mathematical description (like Wiecki et al. 2013)
# --------------------------------------------------


# --- Fixed mathematical description ---
math_block = (
    r"$v_{g,s,c} \sim \mathcal{N}(\mu_v, \sigma_v)$" "\n"
    r"$a_{g,s,c} \sim \mathcal{N}(\mu_a, \sigma_a)$" "\n"
    r"$t_{g,s,c} \sim \mathcal{N}(\mu_t, \sigma_t)$" "\n"
    r"$(RT_{i,t},\, C_{i,t}) \sim \mathrm{DDM}(v_{g,s,c},\, a_{g,s,c},\, t_{g,s,c})$"
)

fig.text(0.1, 0.05, math_block, ha="left", va="bottom", fontsize=10, linespacing=1.5)


# Save file
plt.savefig("hddm_tms_pdi_c_diagram_with_math.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# /var/folders/cz/jbpqkvc936gc0lrwm6908lsh0000gn/T/ipykernel_18570/2227711723.py:74: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 93
#      89 fig.text(0.1, 0.05, math_block, ha="left", va="bottom", fontsize=10, linespacing=1.5)
#      92 # Save file
# ---> 93 plt.savefig("hddm_tms_pdi_c_diagram_with_math.png", dpi=300, bbox_inches="tight")
#      94 plt.show()
#
# File ~/miniforge3/envs/hssm_arm_env/lib/python3.10/site-packages/matplotlib/pyplot.py:1228, in savefig(*args, **kwargs)
#    1225 fig = gcf()
#    1226 # savefig default implementation has no return, so mypy is unhappy
#    1227 # presumably this is here because subclasses can return?
# ...

# %%
import daft
import matplotlib.pyplot as plt
import matplotlib as mpl

# ----------------------------
# Fix LaTeX issues
# ----------------------------
mpl.rcParams['text.usetex'] = False  # Use matplotlib's mathtext instead of full LaTeX

# ----------------------------
# Initialize PGM
# ----------------------------
pgm = daft.PGM(aspect=3, dpi=300)

# ----------------------------
# Hyperparameters
# ----------------------------
pgm.add_node("mu_v", r"$\mu_v$", 0.5, 5, fontsize=6)
pgm.add_node("mu_a", r"$\mu_a$", 2, 5, fontsize=6)
pgm.add_node("mu_t", r"$\mu_t$", 3.5, 5, fontsize=6)

pgm.add_node("sigma_v", r"$\sigma_v$", 0.5, 4, fontsize=6)
pgm.add_node("sigma_a", r"$\sigma_a$", 2, 4, fontsize=6)
pgm.add_node("sigma_t", r"$\sigma_t$", 3.5, 4, fontsize=6)

# ----------------------------
# Condition-level parameters
# ----------------------------
pgm.add_node("v_cond", r"$v_{\mathrm{PDI \times Session \times Coherence}}$", 0.5, 3, fontsize=6)
pgm.add_node("a_cond", r"$a_{\mathrm{PDI \times Session \times Coherence}}$", 2, 3, fontsize=6)
pgm.add_node("t_cond", r"$t_{\mathrm{PDI \times Session \times Coherence}}$", 3.5, 3, fontsize=6)

# ----------------------------
# Trial-level observed data
# ----------------------------
pgm.add_node("rt", r"$RT_{i,t}$", 1.5, 1, observed=True, fontsize=9)
pgm.add_node("response", r"$Response_{i,t}$", 3, 1, observed=True, fontsize=9)

# ----------------------------
# Edges
# ----------------------------
for param in ["v", "a", "t"]:
    pgm.add_edge(f"mu_{param}", f"{param}_cond")
    pgm.add_edge(f"sigma_{param}", f"{param}_cond")
    pgm.add_edge(f"{param}_cond", "rt")
    pgm.add_edge(f"{param}_cond", "response")

# ----------------------------
# Plates
# ----------------------------
pgm.add_plate(daft.Plate(
    [-0.5, 3.5, 5, 1.8],
    label="Hyperpriors",
    fontsize=6
))

pgm.add_plate(daft.Plate(
    [-0.5, 1.8, 5, 1.5],
    label="\nPDI=Low/High\nSession=Sham/TMS\nCoherence=Low/High",
    fontsize=6
))

pgm.add_plate(daft.Plate(
    [0.64, 0.2, 3.2, 1.2],
    label="Trials: 2720",
    fontsize=6
))

# ----------------------------
# Render PGM
# ----------------------------
ax = pgm.render()
fig = ax.figure
fig.set_figheight(8)  # make room for math text

# ----------------------------
# Add mathematical description
# ----------------------------
plt.text(
    -0.5, -0.1,
    r"""
Condition-level distributions:
\[
v_{g,s,c} \sim \mathcal{N}(\mu_v,\,\sigma_v), \quad
a_{g,s,c} \sim \mathcal{N}(\mu_a,\,\sigma_a), \quad
t_{g,s,c} \sim \mathcal{N}(\mu_t,\,\sigma_t)
\]

Trial likelihood:
\[
(RT_{i,t},\,C_{i,t}) \sim \mathrm{DDM}(v_{g,s,c},\, a_{g,s,c},\, t_{g,s,c})
\]
""",
    fontsize=8,
    va="top",
)

# ----------------------------
# Save and show
# ----------------------------
plt.tight_layout()
plt.savefig("hddm_tms_pdi_c_diagram_with_math.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# /var/folders/cz/jbpqkvc936gc0lrwm6908lsh0000gn/T/ipykernel_18570/2550367699.py:101: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern Roman
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern Roman
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern Roman
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern Roman
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern Roman
# findfont: Generic family 'serif' not found because none of the following families were found: Computer Modern Roman
# ...

# %%
import daft
import matplotlib.pyplot as plt
import matplotlib as mpl

# Use LaTeX for math rendering
mpl.rcParams['text.usetex'] = True
mpl.rcParams['font.family'] = 'serif'

pgm = daft.PGM(aspect=3, dpi=300)

# Hyperparameters
pgm.add_node("mu_v", r"$\mu_v$", 0.5, 5, fontsize=6)
pgm.add_node("mu_a", r"$\mu_a$", 2, 5, fontsize=6)
pgm.add_node("mu_t", r"$\mu_t$", 3.5, 5, fontsize=6)

pgm.add_node("sigma_v", r"$\sigma_v$", 0.5, 4, fontsize=6)
pgm.add_node("sigma_a", r"$\sigma_a$", 2, 4, fontsize=6)
pgm.add_node("sigma_t", r"$\sigma_t$", 3.5, 4, fontsize=6)

# Condition-level
pgm.add_node("v_cond", r"$v_{\mathrm{PDI \times Session \times Coherence}}$", 0.5, 3, fontsize=6)
pgm.add_node("a_cond", r"$a_{\mathrm{PDI \times Session \times Coherence}}$", 2, 3, fontsize=6)
pgm.add_node("t_cond", r"$t_{\mathrm{PDI \times Session \times Coherence}}$", 3.5, 3, fontsize=6)

# Trial-level observed data
pgm.add_node("rt", r"$RT_{i,t}$", 1.5, 1, observed=True, fontsize=9)
pgm.add_node("response", r"$Response_{i,t}$", 3, 1, observed=True, fontsize=9)

# Edges
for param in ["v", "a", "t"]:
    pgm.add_edge(f"mu_{param}", f"{param}_cond")
    pgm.add_edge(f"sigma_{param}", f"{param}_cond")
    pgm.add_edge(f"{param}_cond", "rt")
    pgm.add_edge(f"{param}_cond", "response")

# Plates
pgm.add_plate(daft.Plate([-0.5, 3.5, 5, 1.8], label="Hyperpriors", fontsize=6))
pgm.add_plate(daft.Plate([-0.5, 1.8, 5, 1.5], label="\nPDI=Low/High\nSession=Sham/TMS\nCoherence=Low/High", fontsize=6))
pgm.add_plate(daft.Plate([0.64, 0.2, 3.2, 1.2], label="Trials: 2720", fontsize=6))

# Render PGM
ax = pgm.render()
fig = ax.figure
fig.set_figheight(8)

# Add mathematical description below
plt.text(
    -0.5, -0.1,
    r"""
Condition-level distributions:
\[
v_{g,s,c} \sim \mathcal{N}(\mu_v,\,\sigma_v), \quad
a_{g,s,c} \sim \mathcal{N}(\mu_a,\,\sigma_a), \quad
t_{g,s,c} \sim \mathcal{N}(\mu_t,\,\sigma_t)
\]

Trial likelihood:
\[
(RT_{i,t},\,C_{i,t}) \sim \mathrm{DDM}(v_{g,s,c},\, a_{g,s,c},\, t_{g,s,c})
\]
""",
    fontsize=10,
    va="top",
)

plt.savefig("hddm_tms_pdi_c_diagram_with_math.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[18], line 66
#      46 # Add mathematical description below
#      47 plt.text(
#      48     -0.5, -0.1,
#      49     r"""
#    (...)
#      63     va="top",
#      64 )
# ---> 66 plt.savefig("hddm_tms_pdi_c_diagram_with_math.png", dpi=300, bbox_inches="tight")
#      67 plt.show()
#
# File ~/miniforge3/envs/hssm_arm_env/lib/python3.10/site-packages/matplotlib/pyplot.py:1228, in savefig(*args, **kwargs)
#    1225 fig = gcf()
#    1226 # savefig default implementation has no return, so mypy is unhappy
#    1227 # presumably this is here because subclasses can return?
# -> 1228 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1229 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1230 return res
#
# ...
